# %%
# Imports
import pandas as pd

# %%
import pandas_profiling

# %%
# Importa os dados dos arquivo .csv
cvlis_mossoro = pd.read_csv('Data/CVLIS_MOSSORO_2011_2018.csv', sep=';', encoding='latin1')

# %%
# Tipo do objeto
type(cvlis_mossoro)
# Out:
# pandas.core.frame.DataFrame

# %%
cvlis_mossoro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1518 entries, 0 to 1517
# Data columns (total 17 columns):
# DATA                        1518 non-null object
# ESTADO CIVIL                1518 non-null object
# ETNIA                       1518 non-null object
# GENERO                      1518 non-null object
# IDADE                       1518 non-null int64
# LOG VITIMA                  1515 non-null object
# BAIRRO VIT                  1518 non-null object
# CIDADE VIT                  1518 non-null object
# UF VIT                      1518 non-null object
# LOG OCR                     1518 non-null object
# BAIRRO OCR                  1518 non-null object
# MUNICIPIO OCR               1518 non-null object
# MEIO EMPREGADO              1518 non-null object
# MEIO AUXILIAR               1518 non-null object
# TIPO DE MORTE               1518 non-null object
# CARACTERISCA                1518 non-null object
# INDICADOR COMPORTAMENTAL    1518 non-null object
# ...

# %%
# Retorna as 5 últimas linhas
cvlis_mossoro.tail()
# Out:
#             DATA ESTADO CIVIL   ETNIA     GENERO  IDADE  \
# 1513  15/12/2018  SOLTEIRO(A)   PARDA  MASCULINO     38
# 1514  15/12/2018  SOLTEIRO(A)   PARDA  MASCULINO     22
# 1515  25/12/2018    CASADO(A)  BRANCA  MASCULINO     57
# 1516  26/12/2018  SOLTEIRO(A)   PARDA  MASCULINO     19
# 1517  28/12/2018     IGNORADO   PARDA  MASCULINO     41
#
#                       LOG VITIMA      BAIRRO VIT CIDADE VIT UF VIT  \
# 1513            RUA LUZIA FALCÌO        ABOLICAO    MOSSORO     RN
# 1514       RUA JUVENAL LAMARTINE      BOM JARDIM    MOSSORO     RN
# 1515              SITIO ESTREITO      ITAPETINGA    MOSSORO     RN
# 1516  RUA JOSE DE ALENCAR N¼ 501        PEREIROS    MOSSORO     RN
# 1517       RUA MARIA DE MEDEIROS  BELO HORIZONTE    MOSSORO     RN
#
#                                   LOG OCR         BAIRRO OCR MUNICIPIO OCR  \
# 1513                        AV RIO BRANCO      SANTO ANTONIO       MOSSORO
# ...

# %%
# Gera relatórios de perfil de um DataFrame de pandas
pandas_profiling.ProfileReport(cvlis_mossoro)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...
